# %%
import yfinance as yf
import pandas

# %%
stock_list = ['AAPL', 'MSFT', 'AMZN', 'PEP', 'V', 'PG', 'MA', 'INTC', 'HD', 'T']
data = yf.download(stock_list, start="2012-01-01", end="2020-05-24")
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
data = data['Adj Close']
data
# Out:
#                   AAPL         AMZN          HD       INTC          MA  \
# Date
# 2012-01-03   50.857235   179.029999   35.084248  19.025110   32.629364
# 2012-01-04   51.130558   177.509995   35.583790  19.467018   31.555799
# 2012-01-05   51.698215   177.610001   35.875191  19.691841   31.347670
# 2012-01-06   52.238651   182.610001   35.966774  19.575548   30.503506
# 2012-01-09   52.155792   178.559998   35.991753  19.746109   30.761475
# ...                ...          ...         ...        ...         ...
# 2020-05-18  314.959991  2426.260010  245.350006  59.919998  289.899994
# 2020-05-19  313.140015  2449.330078  238.100006  60.290001  290.730011
# 2020-05-20  319.230011  2497.939941  238.190002  63.099998  298.799988
# 2020-05-21  316.850006  2446.739990  240.880005  61.980000  294.260010
# 2020-05-22  318.890015  2436.879883  241.880005  62.259998  294.910004
#
#                   MSFT         PEP          PG          T           V
# Date
# ...

# %%
data.isna().sum()
# Out:
# AAPL    0
# AMZN    0
# HD      0
# INTC    0
# MA      0
# MSFT    0
# PEP     0
# PG      0
# T       0
# V       0
# dtype: int64
